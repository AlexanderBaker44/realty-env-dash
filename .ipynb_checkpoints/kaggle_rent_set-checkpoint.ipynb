# %%
import pandas as pd

# %%
df = pd.read_csv('data/price.csv')

# %%
df.shape
# Out:
# (13131, 81)

# %%
df.columns
# Out:
# Index(['City Code', 'City', 'Metro', 'County', 'State', 'Population Rank',
#        'November 2010', 'December 2010', 'January 2011', 'February 2011',
#        'March 2011', 'April 2011', 'May 2011', 'June 2011', 'July 2011',
#        'August 2011', 'September 2011', 'October 2011', 'November 2011',
#        'December 2011', 'January 2012', 'February 2012', 'March 2012',
#        'April 2012', 'May 2012', 'June 2012', 'July 2012', 'August 2012',
#        'September 2012', 'October 2012', 'November 2012', 'December 2012',
#        'January 2013', 'February 2013', 'March 2013', 'April 2013', 'May 2013',
#        'June 2013', 'July 2013', 'August 2013', 'September 2013',
#        'October 2013', 'November 2013', 'December 2013', 'January 2014',
#        'February 2014', 'March 2014', 'April 2014', 'May 2014', 'June 2014',
#        'July 2014', 'August 2014', 'September 2014', 'October 2014',
#        'November 2014', 'December 2014', 'January 2015', 'February 2015',
# ...

# %%
df.head()
# Out:
#    City Code          City         Metro        County State  Population Rank  \
# 0       6181      New York      New York        Queens    NY                1
# 1      12447   Los Angeles   Los Angeles   Los Angeles    CA                2
# 2      17426       Chicago       Chicago          Cook    IL                3
# 3      39051       Houston       Houston        Harris    TX                4
# 4      13271  Philadelphia  Philadelphia  Philadelphia    PA                5
#
#    November 2010  December 2010  January 2011  February 2011  ...  April 2016  \
# 0            NaN            NaN           NaN            NaN  ...        2334
# 1         2184.0         2184.0        2183.0         2188.0  ...        2637
# 2         1563.0         1555.0        1547.0         1537.0  ...        1684
# 3         1198.0         1199.0        1199.0         1200.0  ...        1444
# 4         1092.0         1099.0        1094.0         1087.0  ...        1206
#
# ...

# %%
len(set(df.City))
# Out:
# 9670

# %%
df.isna().sum().sort_values().tail(20)
# Out:
# March 2013           0
# September 2012       0
# December 2011     1162
# March 2012        1162
# February 2012     1162
# January 2012      1162
# Metro             1232
# October 2011      1383
# November 2011     1383
# September 2011    1397
# August 2011       1399
# June 2011         1399
# May 2011          1399
# July 2011         1399
# April 2011        1409
# March 2011        1458
# February 2011     1631
# November 2010     1783
# January 2011      1783
# December 2010     1783
# dtype: int64

# %%
#start on Jan 2013

# %%
#10 percent of the values are blank these can be eliminated

# %%
df['6 Year Change'] = df['December 2010'] - df['December 2016']

# %%
for i in df.columns:
    if 'December 20' in i and '10' not in i:
        split_list = i.split(' ')
        df[f'{split_list[0]}_{split_list[1]}_{int(split_list[1])-1}'] = df[f'{split_list[0]} {split_list[1]}']-df[f'{split_list[0]} {int(split_list[1])-1}']

# %%
col_list = [i for i in df.columns if '_20' in i]
print(col_list)
average_momentum = df[col_list].fillna(0).sum(axis=1)
average_momentum
df['average_momentum'] = average_momentum/len(col_list)
# Out:
# ['December_2011_2010', 'December_2012_2011', 'December_2013_2012', 'December_2014_2013', 'December_2015_2014', 'December_2016_2015']

# %%
df
# Out:
#        City Code                 City         Metro        County State  \
# 0           6181             New York      New York        Queens    NY
# 1          12447          Los Angeles   Los Angeles   Los Angeles    CA
# 2          17426              Chicago       Chicago          Cook    IL
# 3          39051              Houston       Houston        Harris    TX
# 4          13271         Philadelphia  Philadelphia  Philadelphia    PA
# ...          ...                  ...           ...           ...   ...
# 13126     397405    Highland Township    Gettysburg         Adams    PA
# 13127     398292  Town of Wrightstown     Green Bay         Brown    WI
# 13128     398343               Urbana       Corning       Steuben    NY
# 13129     398839               Angels           NaN     Calaveras    CA
# 13130     737788      Lebanon Borough      New York     Hunterdon    NJ
#
#        Population Rank  November 2010  December 2010  January 2011  \
# ...

# %%
df_sq_ft = pd.read_csv('data/pricepersqft.csv')

# %%
df_sq_ft.shape
# Out:
# (11919, 81)

# %%
df_sq_ft.columns
# Out:
# Index(['City Code', 'City', 'Metro', 'County', 'State', 'Population Rank',
#        'November 2010', 'December 2010', 'January 2011', 'February 2011',
#        'March 2011', 'April 2011', 'May 2011', 'June 2011', 'July 2011',
#        'August 2011', 'September 2011', 'October 2011', 'November 2011',
#        'December 2011', 'January 2012', 'February 2012', 'March 2012',
#        'April 2012', 'May 2012', 'June 2012', 'July 2012', 'August 2012',
#        'September 2012', 'October 2012', 'November 2012', 'December 2012',
#        'January 2013', 'February 2013', 'March 2013', 'April 2013', 'May 2013',
#        'June 2013', 'July 2013', 'August 2013', 'September 2013',
#        'October 2013', 'November 2013', 'December 2013', 'January 2014',
#        'February 2014', 'March 2014', 'April 2014', 'May 2014', 'June 2014',
#        'July 2014', 'August 2014', 'September 2014', 'October 2014',
#        'November 2014', 'December 2014', 'January 2015', 'February 2015',
# ...

# %%
df_sq_ft.head()
# Out:
#    City Code          City         Metro        County State  Population Rank  \
# 0       6181      New York      New York        Queens    NY                1
# 1      12447   Los Angeles   Los Angeles   Los Angeles    CA                2
# 2      17426       Chicago       Chicago          Cook    IL                3
# 3      39051       Houston       Houston        Harris    TX                4
# 4      13271  Philadelphia  Philadelphia  Philadelphia    PA                5
#
#    November 2010  December 2010  January 2011  February 2011  ...  April 2016  \
# 0            NaN            NaN           NaN            NaN  ...       1.806
# 1          1.578          1.578         1.580          1.582  ...       1.990
# 2          1.244          1.248         1.254          1.254  ...       1.354
# 3          0.788          0.784         0.784          0.786  ...       0.984
# 4          0.854          0.858         0.858          0.858  ...       0.948
#
# ...

# %%
df_sq_ft.isna().sum().sort_values().tail(20)
# Out:
# March 2013           0
# September 2012       0
# December 2011      799
# March 2012         799
# February 2012      799
# January 2012       799
# Metro              916
# October 2011      1019
# November 2011     1019
# September 2011    1033
# August 2011       1034
# June 2011         1034
# May 2011          1034
# July 2011         1034
# April 2011        1041
# March 2011        1090
# February 2011     1175
# November 2010     1319
# January 2011      1319
# December 2010     1319
# dtype: int64

# %%
#group on price and square footage
#multiple p_sq_ft by price and perform the grouping
#this can be availible with the time series analysis
#sqft can be a feature
